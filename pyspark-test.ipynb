# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as sp_sum, array, concat_ws, regexp_replace, explode, split


# Spark 세션 생성
spark = SparkSession \
    .builder \
    .appName("PySparkTest") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()


# csv 경로
csv_path = '/Users/b06/Desktop/yeardream/medi-05/data/meta_sample.csv'


# 데이터 로드
df = spark.read.csv(json_path, header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- BaseNaverBlog:kundaeclinic: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- categoryNo: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |-- BusStation:104231: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- BusStation:194123: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- BusStation:194124: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- BusStation:86157: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- BusStation:86158: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- BusStation:93484: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- innerRoutes: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- routeType: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- innerRoute: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- typeName: string (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |-- FsasReview:blog_청구경희한의원 아현점_223218840741_공덕역일요일진료 사고가 생겼다면: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- authorName: string (nullable = true)
#  |    |-- bySmartEditor3: boolean (nullable = true)
#  |    |-- bypassToken: string (nullable = true)
#  |    |-- contents: string (nullable = true)
#  |    |-- createdString: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- hasNaverReservation: boolean (nullable = true)
#  |    |-- home: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- isOfficial: boolean (nullable = true)
#  |    |-- isRepresentative: string (nullable = true)
#  |    |-- isVideoThumbnail: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- profileImageUrl: string (nullable = true)
#  |    |-- rank: string (nullable = true)
#  |    |-- reviewId: string (nullable = true)
#  |    |-- thumbnailCount: string (nullable = true)
#  |    |-- thumbnailUrl: string (nullable = true)
#  |    |-- thumbnailUrlList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- title: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- typeName: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- FsasReview:blog_청구경희한의원 아현점_223222015488_아현공휴일한의원 추석 진료 안내: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- authorName: string (nullable = true)
#  |    |-- bySmartEditor3: boolean (nullable = true)
#  |    |-- bypassToken: string (nullable = true)
#  |    |-- contents: string (nullable = true)
#  |    |-- createdString: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- hasNaverReservation: boolean (nullable = true)
#  |    |-- home: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- isOfficial: boolean (nullable = true)
#  |    |-- isRepresentative: string (nullable = true)
#  |    |-- isVideoThumbnail: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- profileImageUrl: string (nullable = true)
#  |    |-- rank: string (nullable = true)
#  |    |-- reviewId: string (nullable = true)
#  |    |-- thumbnailCount: string (nullable = true)
#  |    |-- thumbnailUrl: string (nullable = true)
#  |    |-- thumbnailUrlList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- title: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- typeName: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- FsasReview:blog_청구경희한의원 아현점_223227655592_공덕동교통사고후유증 더 이상 미루지 말고: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- authorName: string (nullable = true)
#  |    |-- bySmartEditor3: boolean (nullable = true)
#  |    |-- bypassToken: string (nullable = true)
#  |    |-- contents: string (nullable = true)
#  |    |-- createdString: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- hasNaverReservation: boolean (nullable = true)
#  |    |-- home: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- isOfficial: boolean (nullable = true)
#  |    |-- isRepresentative: string (nullable = true)
#  |    |-- isVideoThumbnail: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- profileImageUrl: string (nullable = true)
#  |    |-- rank: string (nullable = true)
#  |    |-- reviewId: string (nullable = true)
#  |    |-- thumbnailCount: string (nullable = true)
#  |    |-- thumbnailUrl: string (nullable = true)
#  |    |-- thumbnailUrlList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- title: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- typeName: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- HospitalBase:1934828030: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- address: string (nullable = true)
#  |    |-- bookingBusinessId: string (nullable = true)
#  |    |-- bookingButtonName: string (nullable = true)
#  |    |-- bookingDisplayName: string (nullable = true)
#  |    |-- bookingHubButtonName: string (nullable = true)
#  |    |-- broadcastInfos: string (nullable = true)
#  |    |-- businessHours: string (nullable = true)
#  |    |-- category: string (nullable = true)
#  |    |-- categoryCode: string (nullable = true)
#  |    |-- categoryCodeList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- categoryCount: long (nullable = true)
#  |    |-- cescoCheck: string (nullable = true)
#  |    |-- cescoLink: string (nullable = true)
#  |    |-- cescofsCheck: string (nullable = true)
#  |    |-- cescofsLink: string (nullable = true)
#  |    |-- chatBotUrl: string (nullable = true)
#  |    |-- conveniences: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- coordinate: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- mapZoomLevel: long (nullable = true)
#  |    |    |-- x: double (nullable = true)
#  |    |    |-- y: double (nullable = true)
#  |    |-- coronaTreatmentTelNo: string (nullable = true)
#  |    |-- defaultCategoryCodeList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- description: string (nullable = true)
#  |    |-- detailPath: string (nullable = true)
#  |    |-- generalHospital: string (nullable = true)
#  |    |-- giftCards: string (nullable = true)
#  |    |-- gifticonId: string (nullable = true)
#  |    |-- gifticonMoreUrl: string (nullable = true)
#  |    |-- hasCoronaMedicalCenter: boolean (nullable = true)
#  |    |-- hasOfficialImages: boolean (nullable = true)
#  |    |-- homepages: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- etc: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- isDeadUrl: boolean (nullable = true)
#  |    |    |    |    |-- isRep: string (nullable = true)
#  |    |    |    |    |-- landingUrl: string (nullable = true)
#  |    |    |    |    |-- order: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- repr: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- isDeadUrl: boolean (nullable = true)
#  |    |    |    |-- isRep: string (nullable = true)
#  |    |    |    |-- landingUrl: string (nullable = true)
#  |    |    |    |-- order: long (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- images: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- desc: string (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- infoTitle: string (nullable = true)
#  |    |    |    |-- number: string (nullable = true)
#  |    |    |    |-- origin: string (nullable = true)
#  |    |    |    |-- source: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |    |-- imagesLastModified: string (nullable = true)
#  |    |-- imagesLastModifiedDate: string (nullable = true)
#  |    |-- is100YearCertified: string (nullable = true)
#  |    |-- isKtis: string (nullable = true)
#  |    |-- keywords: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- mapUrl: string (nullable = true)
#  |    |-- menuImages: string (nullable = true)
#  |    |-- menus: string (nullable = true)
#  |    |-- microReviews: string (nullable = true)
#  |    |-- missingInfo: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- isAccessorMissing: boolean (nullable = true)
#  |    |    |-- isBizHourMissing: boolean (nullable = true)
#  |    |    |-- isBoss: boolean (nullable = true)
#  |    |    |-- isConveniencesMissing: boolean (nullable = true)
#  |    |    |-- isDescriptionMissing: boolean (nullable = true)
#  |    |    |-- isMenuImageMissing: boolean (nullable = true)
#  |    |    |-- needLargeSuggestionBanner: boolean (nullable = true)
#  |    |-- moreBookingReviewsPath: string (nullable = true)
#  |    |-- moreFsasReviewsPath: string (nullable = true)
#  |    |-- morePhotosPath: string (nullable = true)
#  |    |-- moreUGCReviewsPath: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- naverBlog: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- naverBookingHubUrl: string (nullable = true)
#  |    |-- naverBookingPromotion: string (nullable = true)
#  |    |-- naverBookingUrl: string (nullable = true)
#  |    |-- paymentInfo: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- phone: string (nullable = true)
#  |    |-- poiInfo: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- polygon: string (nullable = true)
#  |    |    |-- polyline: string (nullable = true)
#  |    |-- promotionTitle: string (nullable = true)
#  |    |-- rcode: string (nullable = true)
#  |    |-- reportWrongInfoType: string (nullable = true)
#  |    |-- reviewSettings: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- blog: long (nullable = true)
#  |    |    |-- cafe: long (nullable = true)
#  |    |    |-- keyword: string (nullable = true)
#  |    |    |-- showVisitorReviewScore: boolean (nullable = true)
#  |    |-- road: string (nullable = true)
#  |    |-- roadAddress: string (nullable = true)
#  |    |-- routeUrl: string (nullable = true)
#  |    |-- siteId: string (nullable = true)
#  |    |-- staticMapUrl: string (nullable = true)
#  |    |-- streetPanorama: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- talktalkUrl: string (nullable = true)
#  |    |-- themes: string (nullable = true)
#  |    |-- virtualPhone: string (nullable = true)
#  |    |-- visitorReviewsScore: long (nullable = true)
#  |    |-- visitorReviewsTextReviewTotal: long (nullable = true)
#  |    |-- visitorReviewsTotal: long (nullable = true)
#  |    |-- zoomLevel: string (nullable = true)
#  |-- InnerRoute:1073: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:11036973: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:11036981: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:11036997: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:11038300: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1166: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1168: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1242: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1248: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1259: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1275: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1278: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:13003: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1370: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1507: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:1564: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21129: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21149: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21207: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21210: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21213: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:21240: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:510: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:576: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:907: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:909: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:941: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:988: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- InnerRoute:989: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- Panorama:bydPStvfMsdID2iv8PxqvA==: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- lat: string (nullable = true)
#  |    |-- lon: string (nullable = true)
#  |    |-- pan: string (nullable = true)
#  |    |-- tilt: string (nullable = true)
#  |-- ROOT_QUERY: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- accessor: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- accessor: string (nullable = true)
#  |    |    |-- accessorBanner: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- hospital: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- base: struct (nullable = true)
#  |    |    |    |-- __ref: string (nullable = true)
#  |    |    |-- busStations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |-- businessTools: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- hideAnnouncement: boolean (nullable = true)
#  |    |    |    |-- tools: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |-- countInString: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- link: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- using: boolean (nullable = true)
#  |    |    |-- cpImages: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- total: long (nullable = true)
#  |    |    |-- directories: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- countDirectories: string (nullable = true)
#  |    |    |    |-- items: string (nullable = true)
#  |    |    |    |-- total: string (nullable = true)
#  |    |    |    |-- validTabs: string (nullable = true)
#  |    |    |-- excludeTargets: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- image: string (nullable = true)
#  |    |    |    |-- review: string (nullable = true)
#  |    |    |-- fsasReviews: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- items: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |-- maxItemCount: long (nullable = true)
#  |    |    |    |-- total: long (nullable = true)
#  |    |    |-- hasCoupon: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- count: long (nullable = true)
#  |    |    |-- hospitalInfo: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- dayERTel: string (nullable = true)
#  |    |    |    |-- exclServiceInfo: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- ext_key: string (nullable = true)
#  |    |    |    |-- holidayTreat: string (nullable = true)
#  |    |    |    |-- isDayERAvailable: boolean (nullable = true)
#  |    |    |    |-- isNightERAvailable: boolean (nullable = true)
#  |    |    |    |-- isSpecialistInfoHidden: boolean (nullable = true)
#  |    |    |    |-- lunchSat: string (nullable = true)
#  |    |    |    |-- lunchWeek: string (nullable = true)
#  |    |    |    |-- nightChildTreat: string (nullable = true)
#  |    |    |    |-- nightERTel: string (nullable = true)
#  |    |    |    |-- saturdayHours: string (nullable = true)
#  |    |    |    |-- sortedSubjects: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |-- code: long (nullable = true)
#  |    |    |    |    |    |-- count: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- specialEquipments: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- specialOperations: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- specialSubjects: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- subjects: string (nullable = true)
#  |    |    |    |-- sundayTreat: string (nullable = true)
#  |    |    |    |-- weekdayHours: string (nullable = true)
#  |    |    |-- kinQna: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- answerCount: string (nullable = true)
#  |    |    |    |-- answerList: string (nullable = true)
#  |    |    |    |-- profileUrl: string (nullable = true)
#  |    |    |-- newBusinessHours: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- businessHours: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |    |-- breakHours: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |-- businessHours: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |    |-- day: string (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- lastOrderTimes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- time: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- businessStatusDescription: struct (nullable = true)
#  |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |-- blindDescription: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |    |-- comingIrregularClosedDays: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- comingRegularClosedDays: string (nullable = true)
#  |    |    |    |    |-- freeText: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- recentBlogPost: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- isPostExists: boolean (nullable = true)
#  |    |    |    |-- postList: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- screeningClinic: string (nullable = true)
#  |    |    |-- subwayStations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- no: string (nullable = true)
#  |    |    |    |    |-- priority: long (nullable = true)
#  |    |    |    |    |-- station: struct (nullable = true)
#  |    |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |    |-- transfers: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- no: string (nullable = true)
#  |    |    |    |    |    |    |-- priority: long (nullable = true)
#  |    |    |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |-- typeDesc: string (nullable = true)
#  |    |    |-- vaccineQuantity: string (nullable = true)
#  |    |    |-- visitorReviewStats: string (nullable = true)
#  |    |-- panoramaThumbnail: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- myplace: struct (nullable = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- profile: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- borderImageUrl: string (nullable = true)
#  |    |    |    |    |-- imageUrl: string (nullable = true)
#  |    |    |-- partnerHashedIdNo: string (nullable = true)
#  |    |-- vaccineQuantity: string (nullable = true)
#  |    |-- visitorReviewMediasTotal: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- total: long (nullable = true)
#  |    |-- visitorReviewStats: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- visitorReviews: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- hideProductSelectBox: string (nullable = true)
#  |    |    |-- items: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |-- starDistribution: string (nullable = true)
#  |    |    |-- total: long (nullable = true)
#  |-- SubwayStationInfo:241: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nearestExit: string (nullable = true)
#  |    |-- nearestExitType: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |    |-- walkingDistance: long (nullable = true)
#  |-- SubwayStationInfo:242: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nearestExit: string (nullable = true)
#  |    |-- nearestExitType: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |    |-- walkingDistance: long (nullable = true)
#  |-- SubwayStationInfo:243: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nearestExit: string (nullable = true)
#  |    |-- nearestExitType: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |    |-- walkingDistance: long (nullable = true)
#  |-- SubwayStationInfo:530: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nearestExit: string (nullable = true)
#  |    |-- nearestExitType: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |    |-- walkingDistance: long (nullable = true)
#  |-- SubwayStationInfo:531: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lng: double (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- nearestExit: string (nullable = true)
#  |    |-- nearestExitType: string (nullable = true)
#  |    |-- walkTime: long (nullable = true)
#  |    |-- walkingDistance: long (nullable = true)
#  |-- VisitorReview:651249771a24e0b7fae3cfb2: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- author: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- body: string (nullable = true)
#  |    |-- businessName: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- highlightOffsets: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- item: string (nullable = true)
#  |    |-- language: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- originType: string (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- receiptInfoUrl: string (nullable = true)
#  |    |-- reply: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- editUrl: string (nullable = true)
#  |    |    |-- editedBy: string (nullable = true)
#  |    |    |-- isReported: boolean (nullable = true)
#  |    |    |-- isSuspended: boolean (nullable = true)
#  |    |    |-- replyTitle: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- tags: string (nullable = true)
#  |    |-- thumbnail: string (nullable = true)
#  |    |-- translatedText: string (nullable = true)
#  |    |-- viewCount: long (nullable = true)
#  |    |-- visitCount: long (nullable = true)
#  |    |-- visited: string (nullable = true)
#  |-- VisitorReview:6514d72716e7b0976bab28d7: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- author: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- body: string (nullable = true)
#  |    |-- businessName: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- highlightOffsets: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- item: string (nullable = true)
#  |    |-- language: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- originType: string (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- receiptInfoUrl: string (nullable = true)
#  |    |-- reply: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- editUrl: string (nullable = true)
#  |    |    |-- editedBy: string (nullable = true)
#  |    |    |-- isReported: boolean (nullable = true)
#  |    |    |-- isSuspended: boolean (nullable = true)
#  |    |    |-- replyTitle: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- tags: string (nullable = true)
#  |    |-- thumbnail: string (nullable = true)
#  |    |-- translatedText: string (nullable = true)
#  |    |-- viewCount: long (nullable = true)
#  |    |-- visitCount: long (nullable = true)
#  |    |-- visited: string (nullable = true)
#  |-- VisitorReview:651be62e95273ea3ae925d34: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- author: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- body: string (nullable = true)
#  |    |-- businessName: string (nullable = true)
#  |    |-- created: string (nullable = true)
#  |    |-- highlightOffsets: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- item: string (nullable = true)
#  |    |-- language: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- originType: string (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- receiptInfoUrl: string (nullable = true)
#  |    |-- reply: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created: string (nullable = true)
#  |    |    |-- editUrl: string (nullable = true)
#  |    |    |-- editedBy: string (nullable = true)
#  |    |    |-- isReported: boolean (nullable = true)
#  |    |    |-- isSuspended: boolean (nullable = true)
#  |    |    |-- replyTitle: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- tags: string (nullable = true)
#  |    |-- thumbnail: string (nullable = true)
#  |    |-- translatedText: string (nullable = true)
#  |    |-- viewCount: long (nullable = true)
#  |    |-- visitCount: long (nullable = true)
#  |    |-- visited: string (nullable = true)
#  |-- VisitorReviewAuthor:3rYQ1: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- borderImageUrl: string (nullable = true)
#  |    |-- from: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- imageUrl: string (nullable = true)
#  |    |-- isFollowing: string (nullable = true)
#  |    |-- review: string (nullable = true)
#  |    |-- theme: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- VisitorReviewAuthor:5nKO: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- borderImageUrl: string (nullable = true)
#  |    |-- from: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- imageUrl: string (nullable = true)
#  |    |-- isFollowing: string (nullable = true)
#  |    |-- review: string (nullable = true)
#  |    |-- theme: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- VisitorReviewStatsResult:1934828030: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- analysis: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- menus: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- themes: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- votedKeyword: string (nullable = true)
#  |    |-- apolloCacheId: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- ratingReviewsTotal: string (nullable = true)
#  |    |-- review: struct (nullable = true)
#  |    |    |-- __typename: string (nullable = true)
#  |    |    |-- authorCount: long (nullable = true)
#  |    |    |-- avgRating: long (nullable = true)
#  |    |    |-- imageReviewCount: long (nullable = true)
#  |    |    |-- maxScoreWithMaxCount: string (nullable = true)
#  |    |    |-- maxSingleReviewScoreCount: string (nullable = true)
#  |    |    |-- scores: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- starDistribution: string (nullable = true)
#  |    |    |-- totalCount: long (nullable = true)
#  |    |-- visitorReviewsTotal: long (nullable = true)

# %%
### 필요 없는 칼럼들은 제외


# 특정 컬럼들만 추출
cols_selected = [
    'review_settings_keyword', 
    'keywords_1', 'keywords_2', 'keywords_3', 'keywords_4', 'keywords_5', 
    'conveniences_1', 'conveniences_2', 'conveniences_3', 'conveniences_4', 'conveniences_5', 
    'conveniences_6', 'conveniences_7', 'conveniences_8', 'conveniences_9', 'conveniences_10', 
    'conveniences_11',     
    'description',
    'id', 'name', 'visitor_reviews_total', 'photo_review_ratio', 'fsas_reviews_total', 
    'images_count', 'homepages_type', 'homepages_isDeadUrl', 'homepages_isRep',
    'description_length', 'self_blog_present', 'qna_answer_count', 'crawled_at',    
]


# Create a new DataFrame with only the selected columns
df_selected = df.select(cols_selected)
df_selected
# Out:
# AC%ED%95%9C%EC%9D%98%EC%9B%90%20%EC%95%84%ED%98%84%EC%A0%90",  "isKtis": null,  "hasOfficialImages": true,  "imagesLastModified": "2023-10-04 13:19:00",  "imagesLastModifiedDate": "2023.10.04.",  "talktalkUrl": null,  "chatBotUrl": null,  "promotionTitle": null,  "naverBookingPromotion": null,  "zoomLevel": null,  "mapUrl": "/hospitals/detailMap?id=1934828030",  "giftCards": null,  "staticMapUrl": "https://simg.pstatic.net/static.map/v2/map/staticmap.bin?center=126.9554094869228%2C37.55614258960924&level=16&dataversion=169.76&caller=naver_mstore&markers=pos%3A126.9554094869228%2037.55614258960924%7Ccolor%3Ablue",  "roadAddress": "서울 마포구 굴레방로 23-1 B1~지상2층 청구경희한의원 아현점",  "address": "아현동 291-2",  "cescoCheck": null,  "cescoLink": null,  "cescofsCheck": null,  "cescofsLink": null,  "moreBookingReviewsPath": null,  "moreUGCReviewsPath": "/hospitals/fsasReviews?id=1934828030&name=%EC%B2%AD%EA%B5%AC%EA%B2%BD%ED%9D%AC%ED%95%9C%EC%9D%98%EC%9B%90%20%EC%95%84%ED%98%84%EC%A0%90",  "moreFsasReviewsPath": null,  "morePhotosPath": "/hospitals/photos?id=1934828030",  "keywords": ["아현역한의원",  "추나요법",  "교통사고후유증",  "골반교정",  "턱관절"],  "reportWrongInfoType": "type1",  "paymentInfo": ["지역화폐(카드, 모바일)",  "제로페이"],  "businessHours": null,  "coordinate": {"__typename": "Coordinate",  "x": 126.9554094869228,  "y": 37.55614258960924,  "mapZoomLevel": 12},  "naverBlog": {"__ref": "BaseNaverBlog:kundaeclinic"},  "homepages": {"__typename": "Homepage",  "etc": [{"__typename": "HomepageRepr",  "url": "https://blog.naver.com/kundaeclinic",  "landingUrl": "https://blog.naver.com/kundaeclinic",  "type": "블로그",  "order": 1,  "isDeadUrl": false274,  "isRep": null},  {"__typename": "HomepageRepr",  "url": "https://www.instagram.com/bluehillclinic_official",  "landingUrl": "https://www.instagram.com/bluehillclinic_official",  "type": "인스타그램",  "order": 2,  "isDeadUrl": false281,  "isRep": null}],  "repr": {"__typename": "HomepageRepr",  "url": "http://ahyeon.bluehillclinic.com",  "landingUrl": "http://ahyeon.bluehillclinic.com",  "isDeadUrl": false286,  "type": "웹사이트",  "order": 0,  "isRep": null}},  "poiInfo": {"__typename": "PoiInfo",  "polyline": null,  "polygon": null},  "visitorReviewsTotal": 121293,  "visitorReviewsScore": 0,  "visitorReviewsTextReviewTotal": 121,  "is100YearCertified": null,  "siteId": "sp_73b4ae332461ec",  "gifticonId": null,  "gifticonMoreUrl": null,  "missingInfo": {"__typename": "MissingInfo",  "isBizHourMissing": true,  "isMenuImageMissing": false,  "isAccessorMissing": false,  "isBoss": false,  "isDescriptionMissing": false,  "isConveniencesMissing": false,  "needLargeSuggestionBanner": true},  "bookingButtonName": "예약",  "coronaTreatmentTelNo": null,  "hasCoronaMedicalCenter": false,  "generalHospital": null},  "FsasReview:blog_청구경희한의원 아현점_223227655592_공덕동교통사고후유증 더 ���상 미루지 말고": {"__typename": "FsasReview",  "name": "청구경희한의원 아현점"313,  "type": "blog"314,  "typeName": "블로그"315,  "url": "https://m.blog.naver.com/bluehill_ah/223227655592",  "home": "https://m.blog.naver.com/bluehill_ah"317,  "id": "blog_청구경희한의원 아현점_223227655592_공덕동교통사고후유증 더 이상 미루지 말고",  "title": "공덕동교통사고후유증 더 이상 미루지 말고",  "rank": "1",  "contents": "공덕동교통사고후유증 더 이상 미루지 말고 안녕하세요. 신체적 신체적 손상과 그에 따른 후유증 치유를 돕는 청구경희한의원 경희아현점입니다. 요즘은 대중교통보다 자가용을 선호하는 추세입니다. 이동의 편리성과... ",  "bySmartEditor3": false322,  "hasNaverReservation": false323,  "thumbnailUrl": "http://blogfiles.naver.net/MjAyMzEwMDRfNjMg/MDAxNjk2MzgzNTQ2OTM2.X5tGD0TucNdVhSJFsLIgFlAfkjQRsW_Jz1rKhtn3t10g.IhA_pJXbywgkOkYQevQjJX1V8H8gileaCqGLw4k9aH8g.JPEG.bluehill_ah/%BE%C6%C7%F6%C1%A1.JPG#608x457",  "thumbnailUrlList": ["http://blogfiles.naver.net/MjAyMzEwMDRfNjMg/MDAxNjk2MzgzNTQ2OTM2.X5tGD0TucNdVhSJFsLIgFlAfkjQRsW_Jz1rKhtn3t10g.IhA_pJXbywgkOkYQevQjJX1V8H8gileaCqGLw4k9aH8g.JPEG.bluehill_ah/%BE%C6%C7%F6%C1%A1.JPG#608x457",  "http://blogfiles.naver.net/MjAyMzEwMDRfNjAg/MDAxNjk2MzgzNTUxNzc0.5pODqtkxDq1WJ39rLWjz-u3j8NZndayphvzVHq_W99Yg._j0MHfq5c5KVxJg01PlKjmJJoFBAH5C_ucPLglRi7AEg.JPEG.bluehill_ah/%BE%C6%C7%F6%C1%A1-%C6%DB%C1%F1_01 ...
# Expected:  "user": {"__typename": "UserResult"1 but found:  "user": {"__typename": "UserResult"
# CSV file: file:///Users/b06/Desktop/yeardream/medi-05/data/naverplace_meta_sample.json
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[18], line 19
#       5 cols_selected = [
#       6     'review_settings_keyword',
#       7     'keywords_1', 'keywords_2', 'keywords_3', 'keywords_4', 'keywords_5',
#    (...)
#      14     'description_length', 'self_blog_present', 'qna_answer_count', 'crawled_at',
#      15 ]
#      18 # Create a new DataFrame with only the selected columns
# ---> 19 df_selected = df.select(cols_selected)
#      20 df_selected
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/pyspark/sql/dataframe.py:3223, in DataFrame.select(self, *cols)
#    3178 def select(self, *cols: "ColumnOrName") -> "DataFrame":  # type: ignore[misc]
#    3179     """Projects a set of expressions and returns a new :class:`DataFrame`.
#    3180
#    3181     .. versionadded:: 1.3.0
#    (...)
#    3221     +-----+---+
#    3222     """
# -> 3223     jdf = self._jdf.select(self._jcols(*cols))
#    3224     return DataFrame(jdf, self.sparkSession)
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `review_settings_keyword` cannot be resolved. Did you mean one of the following? [` "isKtis": null`, ` "avgRating": 0`, ` "cescoLink": null`, ` "isPostExists": true`, ` "postList": []}`].;
# 'Project ['review_settings_keyword, 'keywords_1, 'keywords_2, 'keywords_3, 'keywords_4, 'keywords_5, 'conveniences_1, 'conveniences_2, 'conveniences_3, 'conveniences_4, 'conveniences_5, 'conveniences_6, 'conveniences_7, 'conveniences_8, 'conveniences_9, 'conveniences_10, 'conveniences_11, 'description, 'id, 'name, 'visitor_reviews_total, 'photo_review_ratio, 'fsas_reviews_total, 'images_count, ... 7 more fields]
# +- Relation [[{"ROOT_QUERY": {"__typename": "Query"#427, "user": {"__typename": "UserResult"1#428, "partnerHashedIdNo": null2#429, "myplace": {"__typename": "MyPlaceUserInfo"3#430, "profile": {"__typename": "MyPlaceProfile"4#431, "imageUrl": null5#432, "borderImageUrl": null}}}6#433, "accessor": {"__typename": "Accessor"7#434, "accessor": ""8#435, "accessorBanner": []}9#436, "hospital": null#437, "panoramaThumbnail": {"__typename": "PanoramaThumbnailResult"11#438, "url": "https://apis.naver.com/place/panorama/thumbnail/11779766414141/0?width=800&height=400&msgpad=1696472191134&md=IUhTuI2%2B78CNjKUAfl9NvPkhnYc%3D"}}}#439, {"Panorama:bydPStvfMsdID2iv8PxqvA==": {"__typename": "Panorama"#440, "id": "bydPStvfMsdID2iv8PxqvA=="#441, "pan": "-98.68"#442, "tilt": "16.07"#443, "lon": "126.9556372"#444, "lat": "37.5562007"}#445, "BaseNaverBlog:kundaeclinic": {"__typename": "BaseNaverBlog"#446, "id": "kundaeclinic"#447, "categoryNo": "1"}#448, "HospitalBase:1934828030": {"__typename": "HospitalBase"#449, "id": "1934828030"#450,... 1024 more fields] csv

# %%
### 전처리에 필요한 함수들을 생성
    

def replace_string(df, column_name, pattern, replacement):
    """특정 컬럼의 문자열을 치환하는 함수"""
    return df.withColumn(column_name, regexp_replace(col(column_name), pattern, replacement))
    

def explode_column(df, column_name):
    """특정 컬럼을 분리하고 펼치는 함수"""
    return df.withColumn(column_name, explode(split(col(column_name), ", ")))


def df_id_and_combined_column(df, prefix):
    """특정 접두사를 가진 칼럼들을 하나의 문자열 칼럼으로 합치는 함수"""
    cols = [c for c in df.columns if c.startswith(prefix + "_")]
    cols_arr = array([col(c) for c in cols]).alias(prefix)])
    table = df.select("id", cols_arr)
    return table


def concat_and_explode_column(df, column_name):
    """특정 array 컬럼을 문자열로 변환하고 분리하여 펼치는 함수"""
    return df.withColumn(column_name, explode(split(concat_ws(", ", column_name), ", ")))
# Out:
#   Cell In[19], line 17
#     cols_arr = array([col(c) for c in cols]).alias(prefix)])
#                                                           ^
# SyntaxError: unmatched ']'

# %%
# Table 1: id, review_settings_keyword
table1 = df_selected.select("id", "review_settings_keyword")
table1 = replace_string(table1, "review_settings_keyword", "[()]", "")  # 중괄호와 대괄호는 삭제함
table1 = replace_string(table1, "review_settings_keyword", " & ", ", ") # & -> , -> 제1 정규화
table1 = explode_column(table1, "review_settings_keyword")
table1.show()
# Out:
# +----------+--------------------------------+
# |        id|         review_settings_keyword|
# +----------+--------------------------------+
# |  19518309|                      송정한의원|
# |  19518309|   성동구 | 송정동 | 한의원-일반|
# |  19518309|                      송정한의원|
# |  20709457|               용산구 소망한의원|
# |  19523171|                금호호랑이한의원|
# |  19523171|성동구 | 금호동3가 | 한의원-일반|
# |  19523171|                금호호랑이한의원|
# |  18757770|                      약촌한의원|
# |  18757770|   서초구 | 잠원동 | 한의원-일반|
# |  18757770|                      약촌한의원|
# |1079161835|                      장수한의원|
# |1079161835|   종로구 | 창신동 | 한의원-일반|
# |1079161835|                      장수한의원|
# |1703239053|                  성동예본한의원|
# |1703239053|   성동구 | 행당동 | 한의원-일반|
# |1703239053|                  성동예본한의원|
# |  19529164|                      태평한의원|
# |  19529164|     중구 | 신당동 | 한의원-일반|
# |  19529164|                      태평한의원|
# | 230007709|                    알파스한의원|
# +----------+--------------------------------+
# only showing top 20 rows

# %%
# Table 2: id, keywords
prefix = "keyword"
table2 = df_id_and_combined_column(df_selected, prefix)
table2 = concat_and_explode_column(table2, prefix)
table2.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[21], line 4
#       2 prefix = "keyword"
#       3 table2 = df_id_and_combined_column(df_selected, prefix)
# ----> 4 table2 = concat_and_explode_column(table2, prefix)
#       5 table2.show()
#
# Cell In[4], line 24, in concat_and_explode_column(df, column_name)
#      22 def concat_and_explode_column(df, column_name):
#      23     """특정 array 컬럼을 문자열로 변환하고 분리하여 펼치는 함수"""
# ---> 24     return df.withColumn(column_name, explode(split(concat_ws(", ", column_name), ", ")))
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/pyspark/sql/dataframe.py:5170, in DataFrame.withColumn(self, colName, col)
#    5165 if not isinstance(col, Column):
#    5166     raise PySparkTypeError(
#    5167         error_class="NOT_COLUMN",
#    5168         message_parameters={"arg_name": "col", "arg_type": type(col).__name__},
#    5169     )
# -> 5170 return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/homebrew/Cellar/apache-spark/3.5.0/libexec/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `keyword` cannot be resolved. Did you mean one of the following? [`keywor`, `id`].;
# 'Project [id#17, keywor#3595, explode(split(concat_ws(, , 'keyword), , , -1)) AS keyword#3598]
# +- Project [id#17, array(keywords_1#20, keywords_2#21, keywords_3#22, keywords_4#23, keywords_5#24) AS keywor#3595]
#    +- Project [review_settings_keyword#19, keywords_1#20, keywords_2#21, keywords_3#22, keywords_4#23, keywords_5#24, conveniences_1#41, conveniences_2#42, conveniences_3#43, conveniences_4#44, conveniences_5#45, conveniences_6#46, conveniences_7#47, conveniences_8#48, conveniences_9#49, conveniences_10#50, conveniences_11#51, description#59, id#17, name#18, visitor_reviews_total#29, photo_review_ratio#30, fsas_reviews_total#31, images_count#32, ... 7 more fields]
#       +- Relation [id#17,name#18,review_settings_keyword#19,keywords_1#20,keywords_2#21,keywords_3#22,keywords_4#23,keywords_5#24,menu_name#25,menu_price#26,menu_description#27,menu_images#28,visitor_reviews_total#29,photo_review_ratio#30,fsas_reviews_total#31,images_count#32,naver_booking_url#33,talktalk_url#34,road#35,virtual_phone#36,phone#37,is_smart_phone#38,is_blog_exposed#39,zeropay_available#40,... 22 more fields] csv

# %%
# Table 3: id, conveniences
prefix = "conveniences"
table3 = df_id_and_combined_column(df_selected, prefix)
table3 = concat_and_explode_column(table3, prefix)
table3.show()
# Out:
# +----------+-----------------+
# |        id|     conveniences|
# +----------+-----------------+
# |  19518309|                 |
# |  20709457|                 |
# |  19523171|             주차|
# |  19523171|      무선 인터넷|
# |  18757770|                 |
# |1079161835|                 |
# |1703239053|             주차|
# |1703239053|남/녀 화장실 구분|
# |  19529164|                 |
# | 230007709|                 |
# |  19518394|                 |
# |  19529128|                 |
# |  36523267|             주차|
# |  36523267|             예약|
# |  36523267|남/녀 화장실 구분|
# |  36523267|  장애인 편의시설|
# |  13100633|                 |
# |  19518670|                 |
# |1524076456|             주차|
# |1524076456|             예약|
# +----------+-----------------+
# only showing top 20 rows

# %%
# Table 4: id, description
table4 = df_selected.select("id", "description")
table4.show()
# Out:
# +----------+------------------------------------+
# |        id|                         description|
# +----------+------------------------------------+
# |  19518309|                                NULL|
# |  20709457|                                NULL|
# |  19523171|  대기시간을 최소화하기위해 방문 ...|
# |  18757770|                                NULL|
# |1079161835|    안녕하세요. 늘 환자의 건강을 ...|
# |1703239053|      성동예본한의원은 2022년 7월...|
# |  19529164|                                NULL|
# | 230007709|                                NULL|
# |  19518394|                                NULL|
# |  19529128|                                NULL|
# |  36523267|    대한민국365한의원은 산재 지정...|
# |  13100633|                                NULL|
# |  19518670|                                NULL|
# |1524076456|   안녕하세요! 비수술 척추관절 추...|
# |  19527635|                                NULL|
# |  13153787|                                NULL|
# |  13021125|여성비만만성피로비염통증치료등 한...|
# |  19529179|                                NULL|
# |  18049532|                                NULL|
# |  18044874|                                NULL|
# +----------+------------------------------------+
# only showing top 20 rows

# %%
# Table 5: id와 나머지 모든 컬럼
exclude_cols = [
    'review_settings_keyword',
    'keywords_1', 'keywords_2', 'keywords_3', 'keywords_4', 'keywords_5',
    'conveniences_1', 'conveniences_2', 'conveniences_3', 'conveniences_4', 'conveniences_5',
    'conveniences_6', 'conveniences_7', 'conveniences_8', 'conveniences_9', 'conveniences_10',
    'conveniences_11',
    'description'
]
table5_cols = [col for col in df_selected.columns if col not in exclude_cols]
table5 = df_selected.select(*table5_cols)
table5.show()
# Out:
# +----------+-----------------+---------------------+------------------+------------------+------------+--------------+-------------------+---------------+------------------+-----------------+----------------+--------------------+
# |        id|             name|visitor_reviews_total|photo_review_ratio|fsas_reviews_total|images_count|homepages_type|homepages_isDeadUrl|homepages_isRep|description_length|self_blog_present|qna_answer_count|          crawled_at|
# +----------+-----------------+---------------------+------------------+------------------+------------+--------------+-------------------+---------------+------------------+-----------------+----------------+--------------------+
# |  19518309|       송정한의원|                   22| 0.409090909090909|                 0|           2|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  20709457|       소망한의원|                   22| 0.681818181818182|                 0|           1|          NULL|               NULL|           NULL|                 0|            False|            NULL|2023-10-05 00:00:...|
# |  19523171| 금호호랑이한의원|                   91| 0.351648351648352|                68|           5|          NULL|               NULL|           NULL|                38|            False|            NULL|2023-10-05 00:00:...|
# |  18757770|       약촌한의원|                    5|               0.4|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |1079161835|       장수한의원|                  113| 0.389380530973451|                 2|           5|          NULL|               NULL|           NULL|                92|             NULL|            NULL|2023-10-05 00:00:...|
# |1703239053|   성동예본한의원|                   49|                 0|                 5|           5|          NULL|               NULL|           NULL|               179|             NULL|            NULL|2023-10-05 00:00:...|
# |  19529164|       태평한의원|                   27| 0.481481481481481|                 0|           1|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# | 230007709|     알파스한의원|                   43| 0.441860465116279|                 0|           1|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  19518394|       홍익한의원|                   93| 0.354838709677419|                 2|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  19529128|     신중앙한의원|                    8|               0.5|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  36523267|대한민국365한의원|                   99|0.0909090909090909|               340|          19|          NULL|               NULL|           NULL|              1880|            False|            NULL|2023-10-05 00:00:...|
# |  13100633|       명인한의원|                  262| 0.812977099236641|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  19518670|     도화당한의원|                 NULL|              NULL|                 1|           2|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |1524076456| 마포척편한한의원|                   81| 0.259259259259259|                31|           8|      웹사이트|              False|           NULL|               168|             True|            NULL|2023-10-05 00:00:...|
# |  19527635|       자향한의원|                    6|                 1|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  13153787|       제일한의원|                    2|               0.5|                 0|           5|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  13021125|     소나무한의원|                   37| 0.405405405405405|                 0|           5|          NULL|               NULL|           NULL|                67|            False|            NULL|2023-10-05 00:00:...|
# |  19529179|     소진백한의원|                   89|  0.50561797752809|                 1|           1|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  18049532|     영광당한의원|                 NULL|              NULL|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# |  18044874|       정명한의원|                    1|                 1|                 0|        NULL|          NULL|               NULL|           NULL|                 0|             NULL|            NULL|2023-10-05 00:00:...|
# +----------+-----------------+---------------------+------------------+------------------+------------+--------------+-------------------+---------------+------------------+-----------------+----------------+--------------------+
# only showing top 20 rows

# %%
data_path = '/Users/b06/Desktop/yeardream/medi-05/data/pyspark-test'
table1_path = f"{data_path}/review_settings_keyword"
table2_path = f"{data_path}/keywords"
table3_path = f"{data_path}/conveniences"
table4_path = f"{data_path}/description"
table5_path = f"{data_path}/data"

# %%
def save(table, table_path):
    table\
        .write \
        .mode('overwrite') \
        .option("header", "true") \
        .option("charset", "cp949") \
        .csv(table_path)

# %%
save(table1, table1_path)
save(table2, table2_path)
save(table3, table3_path)
save(table4, table4_path)
save(table5, table5_path)
